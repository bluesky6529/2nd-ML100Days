# %% [markdown]
# # 統計指標實作範例
# ## 常見於迴歸問題的評估指標
# * Mean Absolute Error (MAE)
# * Mean Squared Error (MSE)
#
# ## 常見於分類問題的指標
# * Binary Cross Entropy (CE)
#
# ##### 後面的課程還會有更詳細的說明

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.799

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
def mean_square_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    return sum((y - yp)**2) / len(y) 

MAE = mean_square_error(y, y_hat)
print("The Mean square error is %.3f" % (MAE))
# Out:
# [ -6.53501903 -13.78670864   5.01584055  28.15129057  10.17183894
#    1.53863841  31.80557594  44.30441071  22.92141543  28.95750465
#   13.21108898   5.12022958  20.21675831  34.47179367  55.89348703
#   59.42777159  29.44203527  76.14158886  50.30391019  66.70228045
#   81.81162624 101.4128957   68.23977781  53.28854879  90.91033102
#   88.7171784   69.97772768  88.44676221  80.09118892  95.80390053
#   96.2341463   99.69257699 113.57069864 139.07910928 127.45847491
#  101.37622345  83.99913743 115.38994394 109.28708004 127.88480282
#  131.0665738   92.97550516 135.73682226 126.67223162 125.83092807
#  150.68613433 145.42503216 115.62626242 137.33247457 131.67436887
#  159.25143041 131.22473405 156.98576543 128.69258125 195.8944075
#  187.59238455 172.23686918 165.9934945  180.76082324 175.11774174
#  178.51297321 193.28290426 160.90844358 188.5083865  203.21096622
#  161.87129421 189.02709353 204.45766868 208.80258561 233.45403498
#  202.50012568 218.74276244 216.78498019 200.39100754 244.78107028
#  216.56194694 224.91742695 233.94876391 232.29950617 228.79916028
#  254.17388563 214.33213689 223.43345248 236.56530453 232.26150598
#  228.68646387 251.3692617  232.85091602 285.02397644 274.52658356
#  274.1668033  269.6048909  325.13478279 310.98641132 275.33036183
#  301.92942127 320.11041607 299.64435202 272.73470191 306.26149334
#  280.16652947]
# [  0.5   3.5   6.5   9.5  12.5  15.5  18.5  21.5  24.5  27.5  30.5  33.5
#   36.5  39.5  42.5  45.5  48.5  51.5  54.5  57.5  60.5  63.5  66.5  69.5
#   72.5  75.5  78.5  81.5  84.5  87.5  90.5  93.5  96.5  99.5 102.5 105.5
#  108.5 111.5 114.5 117.5 120.5 123.5 126.5 129.5 132.5 135.5 138.5 141.5
#  144.5 147.5 150.5 153.5 156.5 159.5 162.5 165.5 168.5 171.5 174.5 177.5
#  180.5 183.5 186.5 189.5 192.5 195.5 198.5 201.5 204.5 207.5 210.5 213.5
